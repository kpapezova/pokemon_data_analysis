# %%
import pandas as pd
import matplotlib

# %%
data_file_path = "pokemon.csv"
pokemon_data = pd.read_csv(data_file_path)
print(type(pokemon_data))
pokemon_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
pokemon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
pokemon_data.shape  # number of rows and columns
# Out:
# (801, 41)

# %%
pokemon_data.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
names = pokemon_data["name"]
print(names)
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 796    Celesteela
# 797       Kartana
# 798      Guzzlord
# 799      Necrozma
# 800      Magearna
# Name: name, Length: 801, dtype: object

# %%
type(names)
# Out:
# pandas.core.series.Series

# %%
pokemon_data["hp"] > 50
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 796     True
# 797     True
# 798     True
# 799     True
# 800     True
# Name: hp, Length: 801, dtype: bool

# %%
pokemon_data[(pokemon_data["hp"] > 50)|(pokemon_data["attack"] > 100)]
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 5       ['Blaze', 'Solar Power']         0.25           1.0             1.0
# 7       ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
pokemon_data.loc[2]
# Out:
# abilities            ['Overgrow', 'Chlorophyll']
# against_bug                                  1.0
# against_dark                                 1.0
# against_dragon                               1.0
# against_electric                             0.5
# against_fairy                                0.5
# against_fight                                0.5
# against_fire                                 2.0
# against_flying                               2.0
# against_ghost                                1.0
# against_grass                               0.25
# against_ground                               1.0
# against_ice                                  2.0
# against_normal                               1.0
# against_poison                               1.0
# against_psychic                              2.0
# against_rock                                 1.0
# against_steel                                1.0
# against_water                                0.5
# ...

# %%
pokemon_data.loc[2:4, "name"]
# Out:
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: name, dtype: object

# %%
pokemon_data.iloc[2,0]    # row number is 2, column number is 0 -> display a specific value
# Out:
# "['Overgrow', 'Chlorophyll']"

# %%
pokemon_data.iloc[:, 0:2]
# Out:
#                        abilities  against_bug
# 0    ['Overgrow', 'Chlorophyll']         1.00
# 1    ['Overgrow', 'Chlorophyll']         1.00
# 2    ['Overgrow', 'Chlorophyll']         1.00
# 3       ['Blaze', 'Solar Power']         0.50
# 4       ['Blaze', 'Solar Power']         0.50
# ..                           ...          ...
# 796              ['Beast Boost']         0.25
# 797              ['Beast Boost']         1.00
# 798              ['Beast Boost']         2.00
# 799              ['Prism Armor']         2.00
# 800               ['Soul-Heart']         0.25
#
# [801 rows x 2 columns]

# %%
pokemon_data["name_upper"] = " "  # addition of comlumn name_upper
pokemon_data.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  pokedex_number  sp_attack  sp_defense  \
# ...

# %%
pokemon_data.drop(["name_upper"], axis=1, inplace=True)    #delete the column name_upper
pokemon_data.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
pokemon_data["name_upper"] = pokemon_data["name"].str.upper()
pokemon_data
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
pokemon_data.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# ...

# %%
pokemon_data["type1"].value_counts()
# Out:
# type1
# water       114
# normal      105
# grass        78
# bug          72
# psychic      53
# fire         52
# rock         45
# electric     39
# poison       32
# ground       32
# dark         29
# fighting     28
# ghost        27
# dragon       27
# steel        24
# ice          23
# fairy        18
# flying        3
# Name: count, dtype: int64

# %% [markdown]
# Histograms

# %%
# to display graphs right after the command
# %matplotlib inline

# %%
pokemon_data.hist(figsize=(30, 30), xlabelsize=20, ylabelsize=20, bins=30)
# Out:
# array([[<Axes: title={'center': 'against_bug'}>,
#         <Axes: title={'center': 'against_dark'}>,
#         <Axes: title={'center': 'against_dragon'}>,
#         <Axes: title={'center': 'against_electric'}>,
#         <Axes: title={'center': 'against_fairy'}>,
#         <Axes: title={'center': 'against_fight'}>],
#        [<Axes: title={'center': 'against_fire'}>,
#         <Axes: title={'center': 'against_flying'}>,
#         <Axes: title={'center': 'against_ghost'}>,
#         <Axes: title={'center': 'against_grass'}>,
#         <Axes: title={'center': 'against_ground'}>,
#         <Axes: title={'center': 'against_ice'}>],
#        [<Axes: title={'center': 'against_normal'}>,
#         <Axes: title={'center': 'against_poison'}>,
#         <Axes: title={'center': 'against_psychic'}>,
#         <Axes: title={'center': 'against_rock'}>,
#         <Axes: title={'center': 'against_steel'}>,
#         <Axes: title={'center': 'against_water'}>],
# ...

# %%
pokemon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
pokemon_columns_selection = pokemon_data[["pokedex_number", "name", "type1", "generation", "hp", "attack", "defense", "speed", "weight_kg", "height_m", "base_happiness", "capture_rate", "is_legendary"]].copy()
pokemon_columns_selection
# Out:
#      pokedex_number        name    type1  generation   hp  attack  defense  \
# 0                 1   Bulbasaur    grass           1   45      49       49
# 1                 2     Ivysaur    grass           1   60      62       63
# 2                 3    Venusaur    grass           1   80     100      123
# 3                 4  Charmander     fire           1   39      52       43
# 4                 5  Charmeleon     fire           1   58      64       58
# ..              ...         ...      ...         ...  ...     ...      ...
# 796             797  Celesteela    steel           7   97     101      103
# 797             798     Kartana    grass           7   59     181      131
# 798             799    Guzzlord     dark           7  223     101       53
# 799             800    Necrozma  psychic           7   97     107      101
# 800             801    Magearna    steel           7   80      95      115
#
# ...

# %%
pokemon_work_data = pokemon_columns_selection[pokemon_columns_selection["generation"] < 3].copy()
pokemon_work_data
# Out:
#      pokedex_number        name    type1  generation   hp  attack  defense  \
# 0                 1   Bulbasaur    grass           1   45      49       49
# 1                 2     Ivysaur    grass           1   60      62       63
# 2                 3    Venusaur    grass           1   80     100      123
# 3                 4  Charmander     fire           1   39      52       43
# 4                 5  Charmeleon     fire           1   58      64       58
# ..              ...         ...      ...         ...  ...     ...      ...
# 246             247     Pupitar     rock           2   70      84       70
# 247             248   Tyranitar     rock           2  100     164      150
# 248             249       Lugia  psychic           2  106      90      130
# 249             250       Ho-Oh     fire           2  106     130       90
# 250             251      Celebi  psychic           2  100     100      100
#
# ...
